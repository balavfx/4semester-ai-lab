# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # create a continues number

# %%
cot_num=pd.DataFrame(np.random.rand(15,1),columns=["Random"])

# %%
cot_num
# Out:
#       Random
# 0   0.485457
# 1   0.873247
# 2   0.394702
# 3   0.332290
# 4   0.303136
# 5   0.836616
# 6   0.236287
# 7   0.819789
# 8   0.980864
# 9   0.821396
# 10  0.036333
# 11  0.417347
# 12  0.302628
# 13  0.804281
# 14  0.547630

# %%
dist_num=pd.DataFrame(np.random.randint(0,8,15),columns=["Discrete"])

# %%
dist_num
# Out:
#     Discrete
# 0          6
# 1          4
# 2          3
# 3          2
# 4          1
# 5          0
# 6          0
# 7          6
# 8          6
# 9          3
# 10         4
# 11         0
# 12         4
# 13         3
# 14         6

# %%
ordinal=pd.DataFrame({'salary':[1700,3700,7900,4100],'class':['low','medium','high','medium']})

# %%
ordinal
# Out:
#    salary   class
# 0    1700     low
# 1    3700  medium
# 2    7900    high
# 3    4100  medium

# %%
nominal=pd.DataFrame({'age':[23,1,33,49],'gender':['Male','Female','Female','Male']})

# %%
nominal
# Out:
#    age  gender
# 0   23    Male
# 1    1  Female
# 2   33  Female
# 3   49    Male
