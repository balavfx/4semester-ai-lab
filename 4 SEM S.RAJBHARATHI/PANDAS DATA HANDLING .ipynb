# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %%
data={"sport":['cricket','football','badmiton'],"players":[11,11,2],"points":[200,5,30]}

# %%
d=pd.DataFrame(data,columns=["sport","players","points"])

# %%
print(d)
# Out:
#       sport  players  points
# 0   cricket       11     200
# 1  football       11       5
# 2  badmiton        2      30

# %%
import numpy as np

# %%
a=pd.DataFrame(np.random.randint(200,500,size=(10,5)),columns=list("abcdf"))

# %%
print(a)
# Out:
#      a    b    c    d    f
# 0  322  494  322  407  312
# 1  380  250  282  394  417
# 2  203  375  293  415  369
# 3  266  353  387  354  271
# 4  451  445  307  486  372
# 5  459  424  394  256  352
# 6  388  282  293  317  251
# 7  482  482  227  496  473
# 8  260  226  361  360  272
# 9  460  341  354  450  439

# %% [markdown]
# # DATA NORMALIZATION

# %%
normalization_df = pd.DataFrame({'x':np.random.randint(-100,100,1000),
                                 'y':np.random.randint(-80,80,1000),
                                 'z':np.random.randint(-150,150,1000)})

# %%
normalization_df
# Out:
#       x   y    z
# 0     4   3  101
# 1    -4 -66  -62
# 2    23  46  -70
# 3    19 -39  136
# 4   -29 -75 -126
# ..   ..  ..  ...
# 995  86   8  -72
# 996 -82  14   58
# 997 -56 -43  -96
# 998  17 -58  -13
# 999  94 -25   41
#
# [1000 rows x 3 columns]

# %%
ax=plt.axes(projection='3d')
ax.scatter3D(normalization_df.x,normalization_df.y,normalization_df.z)
plt.figure()

# %%
from sklearn.preprocessing import Normalizer

# %%
normal = Normalizer()

# %%
normalization_df = normal.fit_transform(normalization_df)

# %%
normalization_df
# Out:
# array([[ 0.03955552,  0.02966664,  0.99877688],
#        [-0.04412958, -0.72813804, -0.68400846],
#        [ 0.26478795,  0.5295759 , -0.80587636],
#        ...,
#        [-0.46992501, -0.36083528, -0.80558574],
#        [ 0.27498157, -0.9381724 , -0.21028002],
#        [ 0.89052533, -0.23684184,  0.38842062]])

# %%
form_df=pd.DataFrame(normalization_df,columns=['a','b','c'])

# %%
form_df
# Out:
#             a         b         c
# 0    0.039556  0.029667  0.998777
# 1   -0.044130 -0.728138 -0.684008
# 2    0.264788  0.529576 -0.805876
# 3    0.133098 -0.273202  0.952704
# 4   -0.194016 -0.501765 -0.842965
# ..        ...       ...       ...
# 995  0.764815  0.071146 -0.640310
# 996 -0.808598  0.138053  0.571935
# 997 -0.469925 -0.360835 -0.805586
# 998  0.274982 -0.938172 -0.210280
# 999  0.890525 -0.236842  0.388421
#
# [1000 rows x 3 columns]

# %%
ax=plt.axes(projection='3d')
ax.scatter3D(form_df.a,form_df.b,form_df.c)
plt.figure()

# %% [markdown]
# # Missing values

# %%
Data={'first score':[100,80,np.nan,95],
      'second score':[30,45,70,np.nan],
      'third score':[np.nan,90,30,50],
     'foruth score':[np.nan,70,80,90],
     'fifth score':[100,200,np.nan,300]}

# %%
score=pd.DataFrame(Data)

# %%
score
# Out:
#    first score  second score  third score  foruth score  fifth score
# 0        100.0          30.0          NaN           NaN        100.0
# 1         80.0          45.0         90.0          70.0        200.0
# 2          NaN          70.0         30.0          80.0          NaN
# 3         95.0           NaN         50.0          90.0        300.0

# %%
score.isnull()
# Out:
#    first score  second score  third score  foruth score  fifth score
# 0        False         False         True          True        False
# 1        False         False        False         False        False
# 2         True         False        False         False         True
# 3        False          True        False         False        False

# %%
score.isnull().sum()
# Out:
# first score     1
# second score    1
# third score     1
# foruth score    1
# fifth score     1
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(missing_values=np.nan,strategy='mean')

# %%
imputer.fit(score)
# Out:
# SimpleImputer()

# %%
imputer.transform(score)
# Out:
# array([[100.        ,  30.        ,  56.66666667,  80.        ,
#         100.        ],
#        [ 80.        ,  45.        ,  90.        ,  70.        ,
#         200.        ],
#        [ 91.66666667,  70.        ,  30.        ,  80.        ,
#         200.        ],
#        [ 95.        ,  48.33333333,  50.        ,  90.        ,
#         300.        ]])
