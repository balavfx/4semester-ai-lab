# %%
import numpy as np
import pandas as pd

# %%
stand_scaler = pd.DataFrame({'x1':np.random.normal(0,2,100),'x2':np.random.normal(3,5,100),'x3':np.random.normal(-2,2,100)})

# %%
stand_scaler
# Out:
#           x1         x2        x3
# 0   1.150209  -1.191440 -3.604926
# 1   3.967003   9.232000  0.151190
# 2   3.734723  13.429549 -0.027965
# 3  -3.458503  -1.583497 -4.323924
# 4  -3.276608   6.018551 -5.623991
# ..       ...        ...       ...
# 95  2.169839   5.910188 -2.256137
# 96 -4.591855   8.605376 -4.182201
# 97 -1.943761  13.405078 -0.451402
# 98  2.495574   4.783025 -0.196326
# 99 -1.558334   4.838562 -3.787580
#
# [100 rows x 3 columns]

# %%
stand_scaler.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# # standard scalar

# %%
from sklearn.preprocessing import StandardScaler

# %%
stand_sca = StandardScaler()

# %%
stand_scaler1 = stand_sca.fit_transform(stand_scaler)

# %%
stand_scaler1
# Out:
# array([[ 0.48119655, -0.72901006, -0.63925908],
#        [ 1.79416465,  1.05474263,  1.0920672 ],
#        [ 1.68589413,  1.77306503,  1.00948843],
#        [-1.66702369, -0.79610231, -0.97067044],
#        [-1.58223854,  0.50482849, -1.56991718],
#        [-1.32485189,  0.7528328 , -0.89103098],
#        [ 0.20932296, -0.72821171, -0.40306152],
#        [-0.09275245, -0.81365977,  0.27329797],
#        [ 1.78700824,  1.68029688, -0.49279873],
#        [ 0.191255  ,  1.66791659, -1.53426344],
#        [-0.69086479, -1.25050877,  0.08550766],
#        [ 0.0521451 ,  0.00428558,  1.74725664],
#        [-0.59386708,  2.41932637, -0.48636109],
#        [ 0.82293039,  1.0432875 , -0.79343284],
#        [-1.22857179, -1.25272728, -0.16141788],
#        [ 0.10637901, -1.43079074,  0.02203466],
#        [ 0.69914618, -0.53237013,  0.57731243],
#        [ 0.63499628, -2.08733814, -0.6342872 ],
#        [ 1.28492085, -0.73323695,  1.70263326],
#        [ 0.35536856, -0.05867463, -0.71956399],
# ...

# %%
stand_scalar2 = pd.DataFrame(stand_scaler1,columns=['x1','x2','x3'])

# %%
stand_scalar2
# Out:
#           x1        x2        x3
# 0   0.481197 -0.729010 -0.639259
# 1   1.794165  1.054743  1.092067
# 2   1.685894  1.773065  1.009488
# 3  -1.667024 -0.796102 -0.970670
# 4  -1.582239  0.504828 -1.569917
# ..       ...       ...       ...
# 95  0.956468  0.486284 -0.017555
# 96 -2.195304  0.947509 -0.905345
# 97 -0.960970  1.768877  0.814311
# 98  1.108300  0.293394  0.931885
# 99 -0.781314  0.302898 -0.723451
#
# [100 rows x 3 columns]

# %%
stand_scalar2.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# # Data pre-processing-scaling ouliers & Normalization

# %%
import numpy as np
import pandas as pd

# %%
outlier_df = pd.DataFrame({'x1':np.concatenate([np.random.normal(20,1,1000),np.random.normal(1,1,23)]),
                           'x2':np.concatenate([np.random.normal(30,1,1000),np.random.normal(50,1,23)])})

# %%
outlier_df
# Out:
#              x1         x2
# 0     21.552640  29.411143
# 1     18.899250  30.618714
# 2     19.862824  28.561473
# 3     20.661242  29.872594
# 4     21.172443  30.077456
# ...         ...        ...
# 1018   0.263278  47.480848
# 1019   3.282919  51.010655
# 1020   3.082303  48.428493
# 1021   0.690409  50.129424
# 1022   0.178826  48.224972
#
# [1023 rows x 2 columns]

# %%
outlier_df.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
from sklearn.preprocessing import RobustScaler

# %%
rs = RobustScaler()

# %%
outlier_df1 = rs.fit_transform(outlier_df)

# %%
outlier_df2 = pd.DataFrame(outlier_df1,columns=['x1','x2'])

# %%
outlier_df2.plot.kde()
# Out:
# <Axes: ylabel='Density'>
